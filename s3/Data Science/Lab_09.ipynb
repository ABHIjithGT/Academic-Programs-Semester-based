# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHIjithGT/Academic-Programs-Semester-based/blob/main/s3/Data%20Science/Lab_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Data
car_age = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]).reshape(-1, 1)
car_speed = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])

# Create and fit the model
model = LinearRegression()
model.fit(car_age, car_speed)

# Get slope and intercept
slope = model.coef_[0]
intercept = model.intercept_

# Print regression equation
print(f"Regression Line: car_speed = {slope:.2f} * car_age + {intercept:.2f}")

print("\n\n")

# Plotting
plt.scatter(car_age, car_speed, color='blue', label='Data Points')
plt.plot(car_age, model.predict(car_age), color='red', label='Regression Line')
plt.scatter(age_to_predict, predicted_speed, color='green', label=f'Predicted (age={age_to_predict})')
plt.xlabel("Car Age (years)")
plt.ylabel("Car Speed (km/h)")
plt.title("Linear Regression: Car Age vs Speed")
plt.legend()
plt.grid(True)
plt.show()

# Predict car speed for car age = 14
print("\n\n")
age_to_predict = 14
predicted_speed = model.predict(np.array([[age_to_predict]]))[0]
print(f"Predicted car speed for age {age_to_predict}: {predicted_speed:.2f} km/h")
# Out:
# Regression Line: car_speed = -1.75 * car_age + 103.11
# Predicted car speed for age 14: 78.59 km/h
