# %%
import pandas as pd

data = {
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, None, 2, 1]
}
df = pd.DataFrame(data)

print("\nHEAD\n", df.head())
print("\nTAIL\n", df.tail())
print("\nCOUNT\n", df.count())
print("\nSUM\n", df.sum())
print("\nMEAN\n", df.mean())
print("\nMEDIAN\n", df.median())
print("\nMODE\n", df.mode())
print("\nSTANDARD DEVIATION\n", df.std())
print("\nMINIMUM\n", df.min())
print("\nMAXIMUM\n", df.max())
print("\nABSOLUTE VALUES\n", df.abs())
print("\nPRODUCT\n", df.prod())
print("\nCUMULATIVE SUM\n", df.cumsum())
print("\nCUMULATIVE PRODUCT\n", df.cumprod())
print("\nINFO\n")
df.info()
print("\nSHAPE\n", df.shape)
print("\nDESCRIBE\n", df.describe())
# Out:
# HEAD
#     A    B
# 0  1  5.0
# 1  2  4.0
# 2  3  NaN
# 3  4  2.0
# 4  5  1.0
#
# TAIL
#     A    B
# 0  1  5.0
# 1  2  4.0
# 2  3  NaN
# 3  4  2.0
# 4  5  1.0
#
# COUNT
#  A    5
# B    4
# dtype: int64
#
# SUM
#  A    15.0
# B    12.0
# dtype: float64
#
# MEAN
#  A    3.0
# B    3.0
# dtype: float64
#
# MEDIAN
#  A    3.0
# B    3.0
# dtype: float64
#
# MODE
#     A    B
# 0  1  1.0
# 1  2  2.0
# 2  3  4.0
# 3  4  5.0
# 4  5  NaN
#
# STANDARD DEVIATION
#  A    1.581139
# B    1.825742
# dtype: float64
#
# MINIMUM
#  A    1.0
# B    1.0
# dtype: float64
#
# MAXIMUM
#  A    5.0
# B    5.0
# dtype: float64
#
# ABSOLUTE VALUES
#     A    B
# 0  1  5.0
# 1  2  4.0
# 2  3  NaN
# 3  4  2.0
# 4  5  1.0
#
# PRODUCT
#  A    120.0
# B     40.0
# dtype: float64
#
# CUMULATIVE SUM
#      A     B
# 0   1   5.0
# 1   3   9.0
# 2   6   NaN
# 3  10  11.0
# 4  15  12.0
#
# CUMULATIVE PRODUCT
#       A     B
# 0    1   5.0
# 1    2  20.0
# 2    6   NaN
# 3   24  40.0
# 4  120  40.0
#
# INFO
#
# ...
