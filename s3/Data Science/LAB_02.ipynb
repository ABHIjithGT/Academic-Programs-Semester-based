# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHIjithGT/Academic-Programs-Semester-based/blob/main/LAB_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pandas.plotting import scatter_matrix, andrews_curves, parallel_coordinates
import plotly.express as px

sns.set(style="whitegrid")

# If you want to upload your own iris.csv:
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('iris.csv')
# Out:
#      <input type="file" id="files-bdfbf0bd-d124-47e6-ad9d-3710708472b3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdfbf0bd-d124-47e6-ad9d-3710708472b3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Show basic info
print("\nHEAD\n", df.head())
print("\nTAIL\n", df.tail())
print("\nCOUNT\n", df.count())
# print("\nSUM\n", df.sum())
# print("\nMEAN\n", df.mean())
# print("\nMEDIAN\n", df.median())
# print("\nMODE\n", df.mode())
# print("\nSTANDARD DEVIATION\n", df.std())
# print("\nMINIMUM\n", df.min())
# print("\nMAXIMUM\n", df.max())
# print("\nABSOLUTE VALUES\n", df.abs())
# print("\nPRODUCT\n", df.prod())
# print("\nCUMULATIVE SUM\n", df.cumsum())
# print("\nCUMULATIVE PRODUCT\n", df.cumprod())
print("\nINFO\n")
df.info()
print("\nSHAPE\n", df.shape)
print("\nDESCRIBE\n", df.describe())
# Out:
# HEAD
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# TAIL
#        Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Checking for Duplicate Values. To drop all repeated rows based "Species"
data = df.drop_duplicates(subset ="Species",)
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 50    51            7.0           3.2            4.7           1.4
# 100  101            6.3           3.3            6.0           2.5
#
#              Species
# 0        Iris-setosa
# 50   Iris-versicolor
# 100   Iris-virginica

# %%
# Checking for Duplicate Rows based on subset ="Species"

duplicate_rows = df[df.duplicated(subset="Species")]
print(duplicate_rows)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# ..              ...
# ...

# %%
# countplot for the target column - Species
sns.countplot(x='Species', data=df, )
plt.show()

# %%
# draw lineplot
sns.lineplot(x="SepalLengthCm", y="SepalWidthCm", data=df)

# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')

plt.show()
# Out:
# /tmp/ipython-input-317238216.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1, 1), loc=2)

# %%
# Show the relationship between the sepal length and sepal width
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm',
                hue='Species', data=df, )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()

# %%
 # Show the relationship between the petal length and petal width
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm',
                hue='Species', data=df, )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # **ANSWER TO THE QUESTIONS**

# %% [markdown]
# **1. Which species has the smallest flowers?**

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
plt.subplot(1,2,2)
sns.boxplot(x="Species", y="PetalWidthCm", data=iris)
plt.show()

# %% [markdown]
# **2. Which feature best separates the three species?**

# %%
sns.pairplot(iris, hue="Species")
plt.show()

# %% [markdown]
# **3. Are sepal dimensions good indicators of species?**

# %%
sns.scatterplot(x="SepalLengthCm", y="SepalWidthCm", hue="Species", data=iris)
plt.show()

# %% [markdown]
# **4. Which two features are most correlated?**

# %%
plt.figure(figsize=(6,4))
sns.heatmap(iris.select_dtypes(include=['float64', 'int64']).corr(), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# **5. How do the sizes of flowers vary across species?**

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(x="Species", y="SepalLengthCm", data=iris)
plt.subplot(2,2,2)
sns.violinplot(x="Species", y="SepalWidthCm", data=iris)
plt.subplot(2,2,3)
sns.violinplot(x="Species", y="PetalLengthCm", data=iris)
plt.subplot(2,2,4)
sns.violinplot(x="Species", y="PetalWidthCm", data=iris)
plt.show()

# %% [markdown]
# # **Summary of Findings from Sample Questions:**
#
# 1.Smallest flowers: Setosa species has the smallest petals.
#
# 2.Best features to separate species: Petal length and petal width.
#
# 3.Sepal dimensions as predictors: Sepal length and width overlap significantly, making them weaker predictors.
#
# 4.Most correlated features: Petal length and petal width.
#
# 5.Variation in flower sizes: Virginica generally has the largest flowers, Setosa the smallest.
